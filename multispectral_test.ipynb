# %%
import cv2
import stackview
import tifffile as tf

# %%
extractor = "superpoint"
img_result = "01442"
transformation = "rigid_ransac"

# %%
extractor = "aliked"
img_result = "01442"
transformation = "homography"

# %%
#non matched
hella = tf.imread(f"/Volumes/T7/NICK/resultados/original/{extractor}/{transformation}_{img_result}.tiff")

# %%
#histogram matching
hella = tf.imread(f"/Volumes/T7/NICK/resultados/haze_left/{extractor}/{transformation}_{img_result}.tiff")

# %%
stackview.switch(
    {
        "red": hella[:, :, 0],
        "green": hella[:, :, 1],
        "blue": hella[:, :, 2],
        "lwir": hella[:, :, 3],
    },
    colormap=["pure_red", "pure_green", "pure_blue", "inferno"],
    toggleable=True,
)
