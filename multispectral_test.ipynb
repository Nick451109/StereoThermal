# %%
# %pip install -r requirements.txt

# %%
# %pip install stackview

# %%
import cv2
import stackview
import tifffile as tf

# %%
hella = tf.imread("rgbt.tiff")

# %%
hella = tf.imread("image_rgbt_registered.tiff")

# %%
hella = tf.imread("results/superpoint/translation_ransac_thermal_20250710_110814.tiff")

# %%
stackview.switch(
    {
        "red": hella[:, :, 0],
        "green": hella[:, :, 1],
        "blue": hella[:, :, 2],
        "lwir": hella[:, :, 3],
    },
    colormap=["pure_red", "pure_green", "pure_blue", "inferno"],
    toggleable=True,
)

# %%
rgbtd = tf.imread("rgbtd.tiff")

stackview.switch(
    {
        "red": rgbtd[:, :, 0],
        "green": rgbtd[:, :, 1],
        "blue": rgbtd[:, :, 2],
        "lwir": rgbtd[:, :, 3],
        "disp": rgbtd[:, :, 4],
    },
    colormap=["pure_red", "pure_green", "pure_blue", "inferno", "gray"],
    toggleable=True,
)
