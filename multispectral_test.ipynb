# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 1)) (4.11.0.86)
# Requirement already satisfied: pypylon in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: Pillow in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: numpy in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 5)) (3.10.3)
# Requirement already satisfied: kornia>=0.6.11 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 6)) (0.8.1)
# Requirement already satisfied: metrics in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 7)) (0.0.2)
# Requirement already satisfied: python-fusion in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: scikit-image in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 9)) (0.25.2)
# Requirement already satisfied: tqdm in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 11)) (4.67.1)
# Requirement already satisfied: tifffile in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 12)) (2025.5.10)
# Requirement already satisfied: timm==0.5.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from -r requirements.txt (line 14)) (0.5.4)
# Requirement already satisfied: torchvision in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from timm==0.5.4->-r requirements.txt (line 14)) (0.22.1)
# Requirement already satisfied: torch>=1.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from timm==0.5.4->-r requirements.txt (line 14)) (2.7.1+cu118)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (3.2.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->-r requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: kornia_rs>=0.1.9 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from kornia>=0.6.11->-r requirements.txt (line 6)) (0.1.9)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->-r requirements.txt (line 9)) (2.37.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->-r requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->-r requirements.txt (line 9)) (1.15.3)
# Requirement already satisfied: colorama in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from tqdm->-r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (4.14.0)
# Requirement already satisfied: fsspec in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (2025.5.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (3.1.6)
# Requirement already satisfied: filelock in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (3.18.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from sympy>=1.13.3->torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from jinja2->torch>=1.4->timm==0.5.4->-r requirements.txt (line 14)) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install stackview
# Out:
# Requirement already satisfied: stackview in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (0.18.0)
# Requirement already satisfied: ipyevents in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (2.0.2)
# Requirement already satisfied: imageio in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (2.37.0)
# Requirement already satisfied: matplotlib in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (3.10.3)
# Requirement already satisfied: toolz in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (1.0.0)
# Requirement already satisfied: ipycanvas in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (0.13.3)
# Requirement already satisfied: ipympl in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (0.9.7)
# Requirement already satisfied: numpy!=1.19.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (1.26.4)
# Requirement already satisfied: wordcloud in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (1.9.4)
# Requirement already satisfied: ipykernel in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (8.1.7)
# Requirement already satisfied: scikit-image in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stackview) (0.25.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from imageio->stackview) (11.2.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipywidgets->stackview) (5.14.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipywidgets->stackview) (8.37.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipywidgets->stackview) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipywidgets->stackview) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipywidgets->stackview) (3.0.15)
# Requirement already satisfied: packaging in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (5.8.1)
# Requirement already satisfied: nest-asyncio in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (1.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (0.1.7)
# Requirement already satisfied: pyzmq>=24 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (6.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (8.6.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (1.8.14)
# Requirement already satisfied: psutil in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipykernel->stackview) (7.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (3.2.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (4.58.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from matplotlib->stackview) (1.3.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->stackview) (0.4)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->stackview) (1.15.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->stackview) (2025.5.10)
# Requirement already satisfied: networkx>=3.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from scikit-image->stackview) (3.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (3.0.51)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (4.14.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (2.19.1)
# Requirement already satisfied: colorama in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (0.4.6)
# Requirement already satisfied: exceptiongroup in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (1.3.0)
# Requirement already satisfied: decorator in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (5.2.1)
# Requirement already satisfied: stack_data in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->stackview) (0.6.3)
# Requirement already satisfied: pywin32>=300 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->stackview) (310)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->stackview) (4.3.8)
# Requirement already satisfied: six>=1.5 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->stackview) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->stackview) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->stackview) (0.2.13)
# Requirement already satisfied: pure-eval in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin-cidis\documents\rgb thermal\stereothermal\venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->stackview) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import stackview
import tifffile as tf

# %%
hella = tf.imread("rgbt.tiff")

# %%
stackview.switch(
{"red":   hella[:,:,0],
  "green":hella[:,:,1],
  "blue":hella[:,:,2],
  "lwir":hella[:,:,3],
},
colormap=["pure_red", "pure_green", "pure_blue", "inferno"],
toggleable=True
)
# Out:
# HBox(children=(VBox(children=(VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=480, width=640),…

# %%
rgbtd = tf.imread("rgbtd.tiff")

stackview.switch(
{"red":   rgbtd[:,:,0],
  "green":rgbtd[:,:,1],
  "blue":rgbtd[:,:,2],
  "lwir":rgbtd[:,:,3],
 "disp":rgbtd[:,:,4]
},
colormap=["pure_red", "pure_green", "pure_blue", "inferno", "gray"],
toggleable=True
)
# Out:
# HBox(children=(VBox(children=(VBox(children=(HBox(children=(VBox(children=(ImageWidget(height=480, width=640),…
